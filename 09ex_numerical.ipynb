# %% [markdown]
# 1\. **2D minimization of a six-hump camelback function**
#
# $$f(x,y) = \left(4-2.1x^2+\frac{x^4}{3} \right) x^2 +xy + (4y^2 -4)y^2$$
#
# has multiple global and local minima.
#
# - Find the global minima of this function
# - How many global minima are there, and what is the function value at those points?
# - What happens for an initial guess of $(x, y) = (0, 0)$?
#
# Hints:
#
# * Variables can be restricted to $-2 < x < 2$ and $-1 < y < 1$.
# * Use `numpy.meshgrid()` and `pylab.imshow()` to find visually the regions.
# * Use `scipy.optimize.minimize()`, optionally trying its optional arguments.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy import optimize
from scipy import fftpack
from scipy.integrate import odeint

# %matplotlib inline

# %%
def func(x,y):
    return ((4-(2.1*(x*x))+((x*x*x*x)/3))*x*x+x*y+(4*(y*y)-4)*y*y)
solution = optimize.minimize_scalar(func, args=(5,))
print("The global minima and the value is given as: \n",solution)
x = np.linspace(-2, 2)
y = np.linspace(-1, 1)
xg, yg = np.meshgrid(x, y)
plt.figure()
plt.imshow(func(xg,yg), extent=[-2, 2, -1, 1],origin="lower")
plt.colorbar()
plt.scatter(solution.x,solution.x)
plt.show()
print("For an initial guess of (𝑥,𝑦)=(0,0) is :",func(0,0))
# Out:
# The global minima and the value is given as:
#       fun: 2393.204768472884
#     nfev: 31
#      nit: 26
#  success: True
#        x: -1.8511718515349764
# For an initial guess of (𝑥,𝑦)=(0,0) is : 0.0

# %% [markdown]
# 2\. **Non-linear ODE: the damped pendulum**
#
# The equation of the motion that a pendulum makes with respect to the angle $\theta$ with the vertical is given by:
#
# $$\frac{d^2\theta}{dt^2} = -\frac{1}{Q} \frac{d\theta}{dt} + \sin\theta + d \cos\Omega t$$
#
# where $t$ is time, $Q$ is the damping factor, $d$ is the forcing amplitude, and $\Omega$ is the driving frequency of the forcing.
#
# This second order ODE needs to be written as two coupled first order ODEs defining a new variable $\omega \equiv d\theta/dt$:
#
# $$\frac{d\theta}{dt} = \omega$$
# $$\frac{d\omega}{dt} = -\frac{1}{Q}\,\omega + \sin\theta + d \cos\Omega t$$
#
# Consider the initial conditions $\theta_0 = \omega_0 = 0$, and $Q = 2.0$, $d = 1.5$, and $\omega = 0.65$.
#
#  - Solve the ODE with `odeint` over a pariod of 200 time steps
#  - Create two plots, one of $\theta$ as a function of the time, and $\omega$ as a function of the time
#  - **Optional**: determine if there is a set of parameters for which the motion is chaotic.

# %%
# given initial conditions and parameters
d=1.5
Q=2.0
theta0=0
omega0=0
omega=0.65
steps=np.linspace(0,200,20)

# the function computing the derivative of the position 
def pend(var,t,d,omega,Q):
    theta, omega = var # i.e theta0 and omega0
    derivative = [omega,-omega/Q + np.sin(theta) + d*np.cos(omega*t)]
    return derivative

# Solving the ODE
ODE = odeint(pend, [theta0, omega0], t=steps, args=(d,omega,Q)) # based on the conditions given
theta, omega = ODE.T
#plotting theta as a function of time
plt.figure()
plt.plot(steps,theta)
plt.xlabel('time')
plt.ylabel('theta')
plt.title('time vs theta')
#plotting omega as a function of time
plt.figure()
plt.plot(steps, omega)
plt.xlabel('time')
plt.ylabel('omega')
plt.title('time vs omega')
plt.show()

# %% [markdown]
# 3\. **FFT of a simple dataset**
#
# Perform a periodicity analysis on the lynxs-hares population, i.e. determine what is the period of the population of these animals.
#
# The dataset is the one dowloaded at the beginning of Lecture 06:
#
#  - `!wget https://www.dropbox.com/s/ebe1cnyd2gm836a/populations.txt -P data/`

# %%
# !wget https://www.dropbox.com/s/ebe1cnyd2gm836a/populations.txt -P data/
# Out:
# --2023-01-17 14:30:12--  https://www.dropbox.com/s/ebe1cnyd2gm836a/populations.txt
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.69.18, 2620:100:6025:18::a27d:4512
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.69.18|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: /s/raw/ebe1cnyd2gm836a/populations.txt [following]
# --2023-01-17 14:30:13--  https://www.dropbox.com/s/raw/ebe1cnyd2gm836a/populations.txt
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://uc9ee1c28a1732fcfe9ad7d1773f.dl.dropboxusercontent.com/cd/0/inline/B0scxa4xUtrWnW67xjnY6qADq1ShLa6goBTXlLpD44q_3p9UITwTXwmy56BPQBMx2pvBNauAQOJHBfAh6ix_B2NJN9YaFiZ3GqADZ-1olsL1Ql043-XuNClugVGceoQH3eqY5AvDiH5Cv8HjroA-d1bx58W_2vf2s-Q4xHyhyrpSPA/file# [following]
# --2023-01-17 14:30:13--  https://uc9ee1c28a1732fcfe9ad7d1773f.dl.dropboxusercontent.com/cd/0/inline/B0scxa4xUtrWnW67xjnY6qADq1ShLa6goBTXlLpD44q_3p9UITwTXwmy56BPQBMx2pvBNauAQOJHBfAh6ix_B2NJN9YaFiZ3GqADZ-1olsL1Ql043-XuNClugVGceoQH3eqY5AvDiH5Cv8HjroA-d1bx58W_2vf2s-Q4xHyhyrpSPA/file
# Resolving uc9ee1c28a1732fcfe9ad7d1773f.dl.dropboxusercontent.com (uc9ee1c28a1732fcfe9ad7d1773f.dl.dropboxusercontent.com)... 162.125.69.15, 2620:100:6025:15::a27d:450f
# Connecting to uc9ee1c28a1732fcfe9ad7d1773f.dl.dropboxusercontent.com (uc9ee1c28a1732fcfe9ad7d1773f.dl.dropboxusercontent.com)|162.125.69.15|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 525 [text/plain]
# Saving to: ‘data/populations.txt.1’
#
# populations.txt.1   100%[===================>]     525  --.-KB/s    in 0s
#
# 2023-01-17 14:30:14 (65,0 MB/s) - ‘data/populations.txt.1’ saved [525/525]

# %%
import numpy as np
data = np.loadtxt('data/populations.txt')
year, hares, lynxes, carrots = data.T
df=pd.DataFrame(data)
df.columns = ['year', 'hare','lynx','carrot']
df.drop(columns=['carrot'])
gdf = df.groupby('year').mean()
print("Mean (hare, lynx):", df.mean(axis=0))
print("Std (hare, lynx):", df.std(axis=0))
# plotting the given data according to the year
plt.plot(year, hares, year, lynxes) 
plt.legend(('Hare', 'Lynx'), loc=(0.75, 0.75))
# Out:
# Mean (hare, lynx): year       1910.000000
# hare      34080.952381
# lynx      20166.666667
# carrot    42400.000000
# dtype: float64
# Std (hare, lynx): year          6.204837
# hare      21413.981859
# lynx      16655.999920
# carrot     3404.555771
# dtype: float64

# %%
# performing the periodicity analysis on the population
pop_fft= fftpack.fft(df,axis=0) #along the rows
#frequencies
f = fftpack.fftfreq(df.shape[0],1) #df.shape[0] = 21 , we choose a unit 1;so we get an array of frequencies
# finding period
period=1/f
plt.figure(figsize=(7, 5))
plt.plot(period, pop_fft,'*')
plt.xlim(0, 20) #otherwise we wont get a realistic plot
plt.xlabel('Period')
plt.ylabel('population_fft')
plt.show()
# Out:
# /tmp/ipykernel_4317/2783728905.py:6: RuntimeWarning: divide by zero encountered in true_divide
#   period=1/f
# /home/shalini/anaconda3/lib/python3.9/site-packages/matplotlib/cbook/__init__.py:1298: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)

# %% [markdown]
# we can see that most of the plot is concentrated between the first 10 years. Therefore the period is 10.

# %% [markdown]
# 4\. **FFT of an image**
#
# Write a filter that removes the periodic noise from the `moonlanding.png` image by using a 2-dimensional FFT.
#
# * Import the image as a 2D numpy array using `plt.imread("images/moonlanding.png")`. Examine the image with `plt.imshow()`, which is heavily contaminated with periodic noise.
# * Check the documentation of the `scipy.fftpack` package, and find the method that performs a 2D FFT. Plot the spectrum (Fourier transform of) the image. **Hint**: use `LogNorm` to plot the colors in log scale:
# ```Python
# from matplotlib.colors import LogNorm
# plt.imshow(image, norm=LogNorm(vmin=5))
# ```
# * Inspect the spectrum, and try to locate the regions of the power spectrum that contain the signal and those which contain the periodic noise. Use array slicing to set the noise regions to zero.
# * Apply the inverse Fourier transform to plot the resulting image.

# %%
from matplotlib.colors import LogNorm

moon_im=plt.imread("images/moonlanding.png")
plt.figure()
plt.imshow(moon_im)
plt.title("original image")
# Out:
# Text(0.5, 1.0, 'original image')

# %%
#2D fft of the image 
moon_2dfft = fftpack.fft2(moon_im)

#plotting the spectrum of the image
def image_fft(moon_2dfft):
    from matplotlib.colors import LogNorm
    # since this is an image ,it is more convenient to Calculate the absolute value element-wise, so we use np.abs
    plt.imshow(np.abs(moon_2dfft), norm=LogNorm(vmin=5))
    plt.colorbar()
plt.figure()
image_fft(moon_2dfft)
plt.title('Fourier transform of the image')
# Out:
# Text(0.5, 1.0, 'Fourier transform of the image')

# %%
#better to create a copy than work on the original fft 
fft_ins = moon_2dfft.copy()

#Inspecting the spectrum 
rows, coloumns = fft_ins.shape 
to_keep = 0.3
fft_ins[int(rows*to_keep):int(rows*(1-to_keep))] = 0 # setting these rows to zero
fft_ins[:, int(coloumns*to_keep):int(coloumns*(1-to_keep))] = 0 # setting these coloumns to zero
plt.figure()

image_fft(fft_ins)
plt.title('Filtered Spectrum')
# Out:
# Text(0.5, 1.0, 'Filtered Spectrum')

# %%
recons_im = fftpack.ifft2(fft_ins).real
plt.figure()
plt.imshow(recons_im)
plt.title('Reconstructed Image')
# Out:
# Text(0.5, 1.0, 'Reconstructed Image')
